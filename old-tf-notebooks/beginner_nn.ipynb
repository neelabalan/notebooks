# %% [markdown]
# # Neural Networks

# %%
import warnings

import h5py
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.utils.class_weight import compute_class_weight

sns.set_theme(style="darkgrid")
tf.random.set_seed(13)
warnings.filterwarnings("ignore")

# %% [markdown]
# - **Data Description**: The data set contains information on various signal tests performed:
#     - Parameters: Various measurable signal parameters.
#     - Signal_Quality: Final signal strength or quality
#
# To build a classifier which can use the given parameters to determine the signal strength or quality.

# %% [markdown]
# ## Data import and Understanding

# %%
# https://www.kaggle.com/datasets/dsrivastava2020/part-123-signalcsv

signals_df = pd.read_csv("data/signal.csv")

# %%
signals_df.shape
# Out:
# (1599, 12)

# %%
signals_df.columns
# Out:
# Index(['Parameter 1', 'Parameter 2', 'Parameter 3', 'Parameter 4',
#        'Parameter 5', 'Parameter 6', 'Parameter 7', 'Parameter 8',
#        'Parameter 9', 'Parameter 10', 'Parameter 11', 'Signal_Strength'],
#       dtype='object')

# %%
signals_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Parameter 1      1599 non-null   float64
#  1   Parameter 2      1599 non-null   float64
#  2   Parameter 3      1599 non-null   float64
#  3   Parameter 4      1599 non-null   float64
#  4   Parameter 5      1599 non-null   float64
#  5   Parameter 6      1599 non-null   float64
#  6   Parameter 7      1599 non-null   float64
#  7   Parameter 8      1599 non-null   float64
#  8   Parameter 9      1599 non-null   float64
#  9   Parameter 10     1599 non-null   float64
#  10  Parameter 11     1599 non-null   float64
#  11  Signal_Strength  1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
signals_df.describe().T
# Out:
#                   count       mean        std      min      25%       50%  \
# Parameter 1      1599.0   8.319637   1.741096  4.60000   7.1000   7.90000
# Parameter 2      1599.0   0.527821   0.179060  0.12000   0.3900   0.52000
# Parameter 3      1599.0   0.270976   0.194801  0.00000   0.0900   0.26000
# Parameter 4      1599.0   2.538806   1.409928  0.90000   1.9000   2.20000
# Parameter 5      1599.0   0.087467   0.047065  0.01200   0.0700   0.07900
# Parameter 6      1599.0  15.874922  10.460157  1.00000   7.0000  14.00000
# Parameter 7      1599.0  46.467792  32.895324  6.00000  22.0000  38.00000
# Parameter 8      1599.0   0.996747   0.001887  0.99007   0.9956   0.99675
# Parameter 9      1599.0   3.311113   0.154386  2.74000   3.2100   3.31000
# Parameter 10     1599.0   0.658149   0.169507  0.33000   0.5500   0.62000
# Parameter 11     1599.0  10.422983   1.065668  8.40000   9.5000  10.20000
# Signal_Strength  1599.0   5.636023   0.807569  3.00000   5.0000   6.00000
#
#                        75%        max
# Parameter 1       9.200000   15.90000
# Parameter 2       0.640000    1.58000
# Parameter 3       0.420000    1.00000
# Parameter 4       2.600000   15.50000
# Parameter 5       0.090000    0.61100
# Parameter 6      21.000000   72.00000
# Parameter 7      62.000000  289.00000
# Parameter 8       0.997835    1.00369
# Parameter 9       3.400000    4.01000
# Parameter 10      0.730000    2.00000
# Parameter 11     11.100000   14.90000
# Signal_Strength   6.000000    8.00000

# %%
signals_df.head()
# Out:
#    Parameter 1  Parameter 2  Parameter 3  Parameter 4  Parameter 5  \
# 0          7.4         0.70         0.00          1.9        0.076
# 1          7.8         0.88         0.00          2.6        0.098
# 2          7.8         0.76         0.04          2.3        0.092
# 3         11.2         0.28         0.56          1.9        0.075
# 4          7.4         0.70         0.00          1.9        0.076
#
#    Parameter 6  Parameter 7  Parameter 8  Parameter 9  Parameter 10  \
# 0         11.0         34.0       0.9978         3.51          0.56
# 1         25.0         67.0       0.9968         3.20          0.68
# 2         15.0         54.0       0.9970         3.26          0.65
# 3         17.0         60.0       0.9980         3.16          0.58
# 4         11.0         34.0       0.9978         3.51          0.56
#
#    Parameter 11  Signal_Strength
# 0           9.4                5
# 1           9.8                5
# 2           9.8                5
# 3           9.8                6
# 4           9.4                5

# %%
signals_df.tail()
# Out:
#       Parameter 1  Parameter 2  Parameter 3  Parameter 4  Parameter 5  \
# 1594          6.2        0.600         0.08          2.0        0.090
# 1595          5.9        0.550         0.10          2.2        0.062
# 1596          6.3        0.510         0.13          2.3        0.076
# 1597          5.9        0.645         0.12          2.0        0.075
# 1598          6.0        0.310         0.47          3.6        0.067
#
#       Parameter 6  Parameter 7  Parameter 8  Parameter 9  Parameter 10  \
# 1594         32.0         44.0      0.99490         3.45          0.58
# 1595         39.0         51.0      0.99512         3.52          0.76
# 1596         29.0         40.0      0.99574         3.42          0.75
# 1597         32.0         44.0      0.99547         3.57          0.71
# 1598         18.0         42.0      0.99549         3.39          0.66
#
#       Parameter 11  Signal_Strength
# 1594          10.5                5
# 1595          11.2                6
# 1596          11.0                6
# 1597          10.2                5
# 1598          11.0                6

# %% [markdown]
# 1.B. Check for missing values and print percentage for each attribute.

# %%
round((signals_df.isnull().sum() / signals_df.isnull().count()) * 100, 2)
# Out:
# Parameter 1        0.0
# Parameter 2        0.0
# Parameter 3        0.0
# Parameter 4        0.0
# Parameter 5        0.0
# Parameter 6        0.0
# Parameter 7        0.0
# Parameter 8        0.0
# Parameter 9        0.0
# Parameter 10       0.0
# Parameter 11       0.0
# Signal_Strength    0.0
# dtype: float64

# %% [markdown]
# **Observation** No null values found

# %%
len(signals_df[signals_df.duplicated()])
# Out:
# 240

# %%
signals_df[signals_df.duplicated(keep=False)]
# Out:
#       Parameter 1  Parameter 2  Parameter 3  Parameter 4  Parameter 5  \
# 0             7.4        0.700         0.00          1.9        0.076
# 4             7.4        0.700         0.00          1.9        0.076
# 9             7.5        0.500         0.36          6.1        0.071
# 11            7.5        0.500         0.36          6.1        0.071
# 22            7.9        0.430         0.21          1.6        0.106
# ...           ...          ...          ...          ...          ...
# 1567          7.2        0.695         0.13          2.0        0.076
# 1579          6.2        0.560         0.09          1.7        0.053
# 1581          6.2        0.560         0.09          1.7        0.053
# 1592          6.3        0.510         0.13          2.3        0.076
# 1596          6.3        0.510         0.13          2.3        0.076
#
#       Parameter 6  Parameter 7  Parameter 8  Parameter 9  Parameter 10  \
# 0            11.0         34.0      0.99780         3.51          0.56
# 4            11.0         34.0      0.99780         3.51          0.56
# 9            17.0        102.0      0.99780         3.35          0.80
# 11           17.0        102.0      0.99780         3.35          0.80
# 22           10.0         37.0      0.99660         3.17          0.91
# ...           ...          ...          ...          ...           ...
# 1567         12.0         20.0      0.99546         3.29          0.54
# 1579         24.0         32.0      0.99402         3.54          0.60
# 1581         24.0         32.0      0.99402         3.54          0.60
# 1592         29.0         40.0      0.99574         3.42          0.75
# 1596         29.0         40.0      0.99574         3.42          0.75
#
#       Parameter 11  Signal_Strength
# 0              9.4                5
# 4              9.4                5
# 9             10.5                5
# 11            10.5                5
# 22             9.5                5
# ...            ...              ...
# 1567          10.1                5
# 1579          11.3                5
# 1581          11.3                5
# 1592          11.0                6
# 1596          11.0                6
#
# [460 rows x 12 columns]

# %%
signals_df.drop_duplicates(inplace=True)

# %%
signals_df.shape
# Out:
# (1359, 12)

# %%
sns.displot(
    signals_df, x="Parameter 1", kind="kde", hue="Signal_Strength", palette="bright"
)

# %%
# Visualising with box plot for Parameter 1
sns.catplot(signals_df, x="Signal_Strength", y="Parameter 1", kind="box")

# %%
parameters = [
    column_name
    for column_name in signals_df.columns
    if "Signal_Strength" != column_name
]

# %%
for param in parameters:
    g = sns.FacetGrid(signals_df, col="Signal_Strength", hue="Signal_Strength")
    g = g.map(sns.histplot, param, kde=True, element="step")
    plt.show()

# %%
signals_df["Signal_Strength"].value_counts()
# Out:
# Signal_Strength
# 5    577
# 6    535
# 7    167
# 4     53
# 8     17
# 3     10
# Name: count, dtype: int64

# %%
ax = sns.displot(signals_df, x="Signal_Strength", kde=True)

# %% [markdown]
# **Observation**
#
# 1. 5 and 6 counts are relatively high. 3 and 8 are relatively low.
# 2. Parameter 4, 5, 6 and 7 have right skewed distribution when considering signal strength 5 and 6

# %% [markdown]
# ## Data preprocessing

# %%
X = signals_df[parameters]
y = signals_df["Signal_Strength"]

# %%
X.shape
# Out:
# (1359, 11)

# %%
y.shape
# Out:
# (1359,)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=13, shuffle=True, stratify=y
)

# %%
print(f"{X_train.shape=}")
print(f"{X_test.shape=}")
print(f"{y_train.shape=}")
print(f"{y_test.shape=}")
# Out:
# X_train.shape=(951, 11)
# X_test.shape=(408, 11)
# y_train.shape=(951,)
# y_test.shape=(408,)

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(10, 5))
sns.histplot(y_train, kde=True, ax=ax1)
ax1.set_title("Train Set")

sns.histplot(y_test, kde=True, ax=ax2)
ax2.set_title("Test Set")
fig.suptitle("Target Variable Distribution in Training and Testing Sets")
plt.show()

# %%
scaler = MinMaxScaler()
scaler.fit(X_train)
# X_train_scaled = pd.DataFrame(scaler.transform(X), columns=X.columns)
X_train_scaled = scaler.transform(X)

# %%
X_test_scaled = scaler.transform(X_test)

# %%
y_train_cat = tf.keras.utils.to_categorical(y_train)
y_test_cat = tf.keras.utils.to_categorical(y_test)

# %%
print(f"{y_train[0]=}")
print(f"{y_train_cat[0]=}")
# Out:
# y_train[0]=5
# y_train_cat[0]=array([0., 0., 0., 0., 0., 0., 1., 0., 0.])

# %%
y_train_cat.shape
# Out:
# (951, 9)

# %% [markdown]
# ## Model Training & Evaluation using Neural Network

# %%
model_1 = tf.keras.models.Sequential(
    [
        tf.keras.layers.Dense(64, activation="relu", input_shape=(X_train.shape[1],)),
        tf.keras.layers.Dense(9, activation="softmax"),
    ]
)

# Compile the model
model_1.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

# %%
history_1 = model_1.fit(
    X_train, y_train_cat, epochs=20, batch_size=16, validation_data=(X_test, y_test_cat)
)
# Out:
# Epoch 1/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1684 - loss: 6.5415 - val_accuracy: 0.4583 - val_loss: 1.4843
# Epoch 2/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 895us/step - accuracy: 0.4275 - loss: 1.4043 - val_accuracy: 0.4926 - val_loss: 1.3174
# Epoch 3/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 865us/step - accuracy: 0.4420 - loss: 1.2648 - val_accuracy: 0.4902 - val_loss: 1.3025
# Epoch 4/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 864us/step - accuracy: 0.4546 - loss: 1.2420 - val_accuracy: 0.4755 - val_loss: 1.3003
# Epoch 5/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 860us/step - accuracy: 0.4567 - loss: 1.2287 - val_accuracy: 0.4804 - val_loss: 1.2998
# Epoch 6/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 855us/step - accuracy: 0.4716 - loss: 1.2179 - val_accuracy: 0.4730 - val_loss: 1.2988
# Epoch 7/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 852us/step - accuracy: 0.4898 - loss: 1.2078 - val_accuracy: 0.4828 - val_loss: 1.2965
# Epoch 8/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 861us/step - accuracy: 0.4870 - loss: 1.1985 - val_accuracy: 0.4828 - val_loss: 1.2936
# Epoch 9/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 856us/step - accuracy: 0.4951 - loss: 1.1898 - val_accuracy: 0.4804 - val_loss: 1.2916
# Epoch 10/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 896us/step - accuracy: 0.5093 - loss: 1.1831 - val_accuracy: 0.4779 - val_loss: 1.2884
# Epoch 11/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 861us/step - accuracy: 0.5113 - loss: 1.1764 - val_accuracy: 0.4755 - val_loss: 1.2858
# Epoch 12/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 857us/step - accuracy: 0.5166 - loss: 1.1702 - val_accuracy: 0.4779 - val_loss: 1.2833
# Epoch 13/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 857us/step - accuracy: 0.5175 - loss: 1.1644 - val_accuracy: 0.4755 - val_loss: 1.2814
# Epoch 14/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 858us/step - accuracy: 0.5145 - loss: 1.1589 - val_accuracy: 0.4779 - val_loss: 1.2775
# Epoch 15/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 854us/step - accuracy: 0.5228 - loss: 1.1532 - val_accuracy: 0.4779 - val_loss: 1.2749
# Epoch 16/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 856us/step - accuracy: 0.5250 - loss: 1.1481 - val_accuracy: 0.4828 - val_loss: 1.2717
# Epoch 17/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 848us/step - accuracy: 0.5259 - loss: 1.1429 - val_accuracy: 0.4853 - val_loss: 1.2679
# Epoch 18/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 857us/step - accuracy: 0.5277 - loss: 1.1378 - val_accuracy: 0.4926 - val_loss: 1.2646
# Epoch 19/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step - accuracy: 0.5354 - loss: 1.1326 - val_accuracy: 0.4853 - val_loss: 1.2634
# Epoch 20/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 853us/step - accuracy: 0.5368 - loss: 1.1279 - val_accuracy: 0.4877 - val_loss: 1.2596

# %%
y_pred = model_1.predict(X_test)
y_pred_int = np.argmax(y_pred, axis=1)
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
print(classification_report(y_test, y_pred_int))
# Out:
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         3
#            4       0.00      0.00      0.00        16
#            5       0.51      0.80      0.63       173
#            6       0.44      0.37      0.40       161
#            7       0.00      0.00      0.00        50
#            8       0.00      0.00      0.00         5
#
#     accuracy                           0.49       408
#    macro avg       0.16      0.20      0.17       408
# weighted avg       0.39      0.49      0.42       408

# %%
def get_history_as_df(history) -> pd.DataFrame:
    history_df = pd.DataFrame(history.history)
    # Melt DataFrame to create long format
    history_df = history_df.reset_index().melt(id_vars="index")
    # Rename columns
    history_df.columns = ["epoch", "metric", "value"]
    return history_df


def plot_train_test_loss(history_df: pd.DataFrame):
    sns.lineplot(
        x="epoch",
        y="value",
        hue="metric",
        data=history_df[
            (history_df["metric"] == "loss") | (history_df["metric"] == "val_loss")
        ],
    )
    plt.title("Train/Test Loss")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.show()


def plot_train_test_accuracy(history_df: pd.DataFrame):
    sns.lineplot(
        x="epoch",
        y="value",
        hue="metric",
        data=history_df[
            (history_df["metric"] == "accuracy")
            | (history_df["metric"] == "val_accuracy")
        ],
    )
    plt.title("Train/Test Accuracy")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.show()

# %%
history_1_df = get_history_as_df(history_1)
plot_train_test_loss(history_1_df)
plot_train_test_accuracy(history_1_df)

# %% [markdown]
# New architecture/update existing architecture in attempt to improve the performance of the model.

# %%
model_2 = tf.keras.models.Sequential(
    [
        tf.keras.layers.Dense(64, activation="relu", input_shape=(X_train.shape[1],)),
        tf.keras.layers.Dense(
            64,
            activation="relu",
        ),
        tf.keras.layers.Dense(9, activation="softmax"),
    ]
)

# Compile the model
model_2.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

# %%
history_2 = model_2.fit(
    X_train, y_train_cat, epochs=20, batch_size=16, validation_data=(X_test, y_test_cat)
)
# Out:
# Epoch 1/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3717 - loss: 5.6113 - val_accuracy: 0.4877 - val_loss: 1.2858
# Epoch 2/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 918us/step - accuracy: 0.4382 - loss: 1.2188 - val_accuracy: 0.4902 - val_loss: 1.2638
# Epoch 3/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 907us/step - accuracy: 0.4602 - loss: 1.2006 - val_accuracy: 0.4951 - val_loss: 1.2543
# Epoch 4/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 886us/step - accuracy: 0.4561 - loss: 1.1927 - val_accuracy: 0.5000 - val_loss: 1.2468
# Epoch 5/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 882us/step - accuracy: 0.4723 - loss: 1.1875 - val_accuracy: 0.5025 - val_loss: 1.2513
# Epoch 6/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 880us/step - accuracy: 0.4756 - loss: 1.1830 - val_accuracy: 0.4951 - val_loss: 1.2473
# Epoch 7/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 880us/step - accuracy: 0.4721 - loss: 1.1763 - val_accuracy: 0.4975 - val_loss: 1.2451
# Epoch 8/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 892us/step - accuracy: 0.4890 - loss: 1.1710 - val_accuracy: 0.4902 - val_loss: 1.2407
# Epoch 9/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 884us/step - accuracy: 0.4969 - loss: 1.1680 - val_accuracy: 0.4951 - val_loss: 1.2424
# Epoch 10/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 917us/step - accuracy: 0.5031 - loss: 1.1620 - val_accuracy: 0.4975 - val_loss: 1.2304
# Epoch 11/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 892us/step - accuracy: 0.5104 - loss: 1.1565 - val_accuracy: 0.4951 - val_loss: 1.2228
# Epoch 12/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 880us/step - accuracy: 0.5056 - loss: 1.1456 - val_accuracy: 0.5000 - val_loss: 1.2228
# Epoch 13/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 879us/step - accuracy: 0.5134 - loss: 1.1427 - val_accuracy: 0.4926 - val_loss: 1.2197
# Epoch 14/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 887us/step - accuracy: 0.5141 - loss: 1.1360 - val_accuracy: 0.4828 - val_loss: 1.2151
# Epoch 15/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 886us/step - accuracy: 0.5253 - loss: 1.1285 - val_accuracy: 0.4877 - val_loss: 1.2070
# Epoch 16/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 880us/step - accuracy: 0.5237 - loss: 1.1218 - val_accuracy: 0.4975 - val_loss: 1.2020
# Epoch 17/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 894us/step - accuracy: 0.5216 - loss: 1.1149 - val_accuracy: 0.5098 - val_loss: 1.1978
# Epoch 18/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 880us/step - accuracy: 0.5191 - loss: 1.1066 - val_accuracy: 0.5049 - val_loss: 1.1926
# Epoch 19/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 887us/step - accuracy: 0.5204 - loss: 1.0999 - val_accuracy: 0.5000 - val_loss: 1.2006
# Epoch 20/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 878us/step - accuracy: 0.5344 - loss: 1.0976 - val_accuracy: 0.4951 - val_loss: 1.1804

# %%
y_pred = model_2.predict(X_test)
y_pred_int = np.argmax(y_pred, axis=1)
print(classification_report(y_test, y_pred_int))
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         3
#            4       0.00      0.00      0.00        16
#            5       0.54      0.69      0.61       173
#            6       0.44      0.50      0.47       161
#            7       0.50      0.04      0.07        50
#            8       0.00      0.00      0.00         5
#
#     accuracy                           0.50       408
#    macro avg       0.25      0.21      0.19       408
# weighted avg       0.46      0.50      0.45       408

# %%
history_2_df = get_history_as_df(history_2)
plot_train_test_loss(history_2_df)
plot_train_test_accuracy(history_2_df)

# %% [markdown]
# The `class_weight` argument in the `fit()` function of TensorFlow allows to give more importance to certain classes or labels in your dataset during training.
# It is useful when dealing with imbalanced datasets where some classes have significantly fewer samples than others.

# %%
# using class weights for imabalanced data

# Compute class weights with sklearn method
class_labels = np.unique(y_train)
class_weights = compute_class_weight(
    class_weight="balanced", classes=class_labels, y=y_train
)
class_weights_map = {
    0: np.float64(0.0),
    1: np.float64(0.0),
    2: np.float64(0.0),
    3: class_weights[0],
    4: class_weights[1],
    5: class_weights[2],
    6: class_weights[3],
    7: class_weights[4],
    8: class_weights[5],
}

# %%
class_weights_map
# Out:
# {0: 0.0,
#  1: 0.0,
#  2: 0.0,
#  3: 22.642857142857142,
#  4: 4.283783783783784,
#  5: 0.39232673267326734,
#  6: 0.42379679144385024,
#  7: 1.3547008547008548,
#  8: 13.208333333333334}

# %%
history_2 = model_2.fit(
    X_train,
    y_train_cat,
    epochs=20,
    batch_size=16,
    class_weight=class_weights_map,
    validation_data=(X_test, y_test_cat),
)
# Out:
# Epoch 1/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3612 - loss: 2.0682 - val_accuracy: 0.2941 - val_loss: 1.6478
# Epoch 2/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.2473 - loss: 1.8465 - val_accuracy: 0.3578 - val_loss: 1.5889
# Epoch 3/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 908us/step - accuracy: 0.3174 - loss: 1.6460 - val_accuracy: 0.3235 - val_loss: 1.6233
# Epoch 4/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 911us/step - accuracy: 0.3312 - loss: 1.5779 - val_accuracy: 0.3456 - val_loss: 1.5932
# Epoch 5/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 944us/step - accuracy: 0.3392 - loss: 1.5329 - val_accuracy: 0.3554 - val_loss: 1.6047
# Epoch 6/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 919us/step - accuracy: 0.3567 - loss: 1.5089 - val_accuracy: 0.3235 - val_loss: 1.6242
# Epoch 7/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 910us/step - accuracy: 0.3344 - loss: 1.4603 - val_accuracy: 0.3284 - val_loss: 1.6013
# Epoch 8/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 947us/step - accuracy: 0.3456 - loss: 1.4297 - val_accuracy: 0.3333 - val_loss: 1.6075
# Epoch 9/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 899us/step - accuracy: 0.3531 - loss: 1.4069 - val_accuracy: 0.3309 - val_loss: 1.6035
# Epoch 10/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 919us/step - accuracy: 0.3449 - loss: 1.3866 - val_accuracy: 0.3309 - val_loss: 1.6041
# Epoch 11/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 951us/step - accuracy: 0.3548 - loss: 1.3594 - val_accuracy: 0.3309 - val_loss: 1.6060
# Epoch 12/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 929us/step - accuracy: 0.3500 - loss: 1.3510 - val_accuracy: 0.3309 - val_loss: 1.5863
# Epoch 13/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 953us/step - accuracy: 0.3615 - loss: 1.3359 - val_accuracy: 0.3260 - val_loss: 1.6054
# Epoch 14/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 929us/step - accuracy: 0.3563 - loss: 1.3139 - val_accuracy: 0.3333 - val_loss: 1.5859
# Epoch 15/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 913us/step - accuracy: 0.3607 - loss: 1.3000 - val_accuracy: 0.3064 - val_loss: 1.6140
# Epoch 16/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 907us/step - accuracy: 0.3377 - loss: 1.2986 - val_accuracy: 0.3211 - val_loss: 1.5996
# Epoch 17/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 929us/step - accuracy: 0.3485 - loss: 1.2839 - val_accuracy: 0.3284 - val_loss: 1.5956
# Epoch 18/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 907us/step - accuracy: 0.3585 - loss: 1.2820 - val_accuracy: 0.3382 - val_loss: 1.5978
# Epoch 19/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 913us/step - accuracy: 0.3419 - loss: 1.2937 - val_accuracy: 0.3186 - val_loss: 1.6439
# Epoch 20/20
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.3329 - loss: 1.2906 - val_accuracy: 0.3235 - val_loss: 1.6123

# %%
y_pred = model_2.predict(X_test)
y_pred_int = np.argmax(y_pred, axis=1)
print(classification_report(y_test, y_pred_int))
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 980us/step
#               precision    recall  f1-score   support
#
#            3       0.02      0.67      0.04         3
#            4       0.05      0.19      0.07        16
#            5       0.69      0.38      0.49       173
#            6       0.55      0.30      0.39       161
#            7       0.31      0.24      0.27        50
#            8       0.04      0.20      0.06         5
#
#     accuracy                           0.32       408
#    macro avg       0.28      0.33      0.22       408
# weighted avg       0.55      0.32      0.40       408

# %% [markdown]
# **Observation**
#
# - Compared to the first model (model_1), second model has better weighted average.
# - The second model when trained with `class_weights` as argument is alble to now classify signals strength for which we don't have much data. These are 3, 4 and 8.
# - In both the cases the model is able to idenitfy the true positives much better for Signal_Strength 5.

# %% [markdown]
# - **Data Description**: The SVHN is a real-world image dataset for developing machine learning and object recognition algorithms with the
# minimal requirement on data formatting but comes from a signi icantly harder, unsolved, real-world problem (recognising digits and
# numbers in natural scene images). SVHN is obtained from house numbers in Google Street View images. Where the labels for each of this image are the prominent number in that image i.e. 2,6,7 and 4 respectively.
#
# To build a digit classifier on the SVHN (Street View Housing Number) dataset.
#
# The dataset has been provided in the form of h5py files. You can read about this ile format here: https://docs.h5py.org/en/stable/
# Acknowledgement: Yuval Netzer, Tao Wang, Adam Coates, Alessandro Bissacco, Bo Wu, Andrew Y. Ng Reading Digits in Natural Images with Unsupervised
# Feature Learning NIPS Workshop on Deep Learning and Unsupervised Feature Learning 2011. PDF
# http://ufldl.stanford.edu/housenumbers as the URL for this site.

# %% [markdown]
# ## Data Import and Exploration

# %%
# https://www.kaggle.com/datasets/sasha18/street-view-house-nos-h5-file
svhn_data = h5py.File("data/SVHN_single_grey1.h5", "r")

# %%
svhn_data.keys()
# Out:
# <KeysViewHDF5 ['X_test', 'X_train', 'X_val', 'y_test', 'y_train', 'y_val']>

# %%
X_train, X_test, y_train, y_test = (
    svhn_data["X_train"],
    svhn_data["X_test"],
    svhn_data["y_train"],
    svhn_data["y_test"],
)

# %%
X_train, X_test, y_train, y_test = (
    np.float64(X_train),
    np.float64(X_test),
    np.int32(y_train),
    np.int32(y_test),
)

# %%
X_train.shape
# Out:
# (42000, 32, 32)

# %% [markdown]
# ## Data Visualisation and preprocessing

# %%
print(f"{X_train.shape=}")
print(f"{X_test.shape=}")
print(f"{y_train.shape=}")
print(f"{y_test.shape=}")
# Out:
# X_train.shape=(42000, 32, 32)
# X_test.shape=(18000, 32, 32)
# y_train.shape=(42000,)
# y_test.shape=(18000,)

# %%
plt.imshow(X_train[0], cmap="gray")
plt.show()

print(f"Label: {y_train[0]}")
# Out:
# Label: 2

# %%
# Train test label distribution
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(10, 5))
sns.histplot(np.array(y_train), ax=ax1, binwidth=0.9)
ax1.set_title("Train Set")

sns.histplot(np.array(y_test), ax=ax2, binwidth=0.9, color="g")
ax2.set_title("Test Set")
fig.suptitle("Target Variable Distribution in Training and Testing Sets")
plt.show()

# %%
fig, axs = plt.subplots(1, 10, figsize=(15, 15))
for i in range(10):
    axs[i].imshow(X_train[i], cmap="gray")
    axs[i].set_title(f"Label: {y_train[i]}")
    axs[i].axis("off")
plt.show()

# %%
X_train = X_train.reshape(X_train.shape[0], -1)
X_test = X_test.reshape(X_test.shape[0], -1)

# %%
X_train.shape
# Out:
# (42000, 1024)

# %%
X_train[0].shape
# Out:
# (1024,)

# %%
scaler = MinMaxScaler()
X_train = X_train.astype("float32")
X_test = X_test.astype("float32")

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# Train test label distribution
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(10, 5))
sns.scatterplot(x=X_train[:, 0], y=X_train[:, 1], ax=ax1)
ax1.set_title("Before Normalization")

sns.scatterplot(x=X_train_scaled[:, 0], y=X_train_scaled[:, 1], ax=ax2)
ax2.set_title("After Normalization")

plt.show()

# %%
y_train_cat = tf.keras.utils.to_categorical(y_train)
y_test_cat = tf.keras.utils.to_categorical(y_test)

# %%
print(f"Total number of classes in train labels: {len(np.unique(y_train))}")
print(f"Total number of classes in test labels: {len(np.unique(y_test))}")
# Out:
# Total number of classes in train labels: 10
# Total number of classes in test labels: 10

# %% [markdown]
# ## Model Training & Evaluation using Neural Network.

# %%
model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(512, activation="relu", input_shape=(1024,)))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.Dropout(0.3))
model.add(tf.keras.layers.Dense(256, activation="relu"))
model.add(tf.keras.layers.Dense(10, activation="softmax"))

model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

# %%
history = model.fit(
    X_train_scaled,
    y_train_cat,
    epochs=15,
    batch_size=32,
    validation_data=(X_test_scaled, y_test_cat),
)
# Out:
# Epoch 1/15
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.3565 - loss: 1.8912 - val_accuracy: 0.4759 - val_loss: 1.6027
# Epoch 2/15
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5435 - loss: 1.3964 - val_accuracy: 0.5508 - val_loss: 1.3836
# Epoch 3/15
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5681 - loss: 1.3209 - val_accuracy: 0.6312 - val_loss: 1.1511
# Epoch 4/15
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.6044 - loss: 1.2303 - val_accuracy: 0.5582 - val_loss: 1.4491
# Epoch 5/15
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.6135 - loss: 1.2112 - val_accuracy: 0.5948 - val_loss: 1.2509
# Epoch 6/15
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.6218 - loss: 1.1779 - val_accuracy: 0.5673 - val_loss: 1.3483
# Epoch 7/15
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.6145 - loss: 1.2020 - val_accuracy: 0.5819 - val_loss: 1.2829
# Epoch 8/15
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.5995 - loss: 1.2287 - val_accuracy: 0.6790 - val_loss: 1.0038
# Epoch 9/15
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.6129 - loss: 1.1959 - val_accuracy: 0.6252 - val_loss: 1.1637
# Epoch 10/15
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.6175 - loss: 1.1834 - val_accuracy: 0.6828 - val_loss: 1.0030
# Epoch 11/15
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.6187 - loss: 1.1768 - val_accuracy: 0.6267 - val_loss: 1.1672
# Epoch 12/15
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.6217 - loss: 1.1678 - val_accuracy: 0.6450 - val_loss: 1.0818
# Epoch 13/15
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.6280 - loss: 1.1516 - val_accuracy: 0.6687 - val_loss: 1.0232
# Epoch 14/15
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.6333 - loss: 1.1458 - val_accuracy: 0.6431 - val_loss: 1.1471
# Epoch 15/15
# 1313/1313 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.6304 - loss: 1.1474 - val_accuracy: 0.6558 - val_loss: 1.0908

# %%
y_pred = model.predict(X_test)
y_pred_int = np.argmax(y_pred, axis=1)
print(classification_report(y_test, y_pred_int))
# Out:
# 563/563 ━━━━━━━━━━━━━━━━━━━━ 0s 548us/step
#               precision    recall  f1-score   support
#
#            0       0.68      0.30      0.41      1814
#            1       0.66      0.40      0.50      1828
#            2       0.22      0.76      0.35      1803
#            3       0.53      0.29      0.37      1719
#            4       0.61      0.67      0.64      1812
#            5       0.36      0.36      0.36      1768
#            6       0.76      0.27      0.39      1832
#            7       0.52      0.36      0.43      1808
#            8       0.46      0.46      0.46      1812
#            9       0.56      0.49      0.52      1804
#
#     accuracy                           0.44     18000
#    macro avg       0.54      0.43      0.44     18000
# weighted avg       0.54      0.44      0.44     18000

# %%
cm = confusion_matrix(y_test, y_pred_int)

sns.heatmap(cm, annot=True, fmt="d")
plt.xlabel("Predicted")
plt.ylabel("Truth")
plt.show()

# %%
# Let's try to visualize images which were mis-classified

misclassified_indices = np.where(y_pred_int != y_test)[0]

# %%
len(misclassified_indices)
# Out:
# 10165

# %%
X_test_copy = scaler.inverse_transform(X_test.copy())
X_test_copy = X_test_copy.reshape(-1, 32, 32, 1)

# %%
for i in range(5):
    index = misclassified_indices[i]
    plt.imshow(X_test_copy[index], cmap='gray')
    plt.title(f"Predicted: {y_pred_int[index]}, Actual: {y_test[index]}")
    plt.axis("off")
    plt.show()

# %%
history_df = get_history_as_df(history)
plot_train_test_loss(history_df)
plot_train_test_accuracy(history_df)

# %% [markdown]
# **Observations**
#
# 1. Using Dropout layer improves the overall model accuracy
# 2. The validation accuracy increases over every epoch and we can notice the training accuracy saturating after 8th epoch.
# 3. In the case of training loss too we see it saturating after 10th epoch and validation loss decreasing.
# 4. We also ploted the images which were misclassified and the observation is some of the images probably have lower resolution to classify them properly.
